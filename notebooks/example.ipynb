# %%
import matplotlib.pyplot as plt 
from sensible.brokers.yahoo_finance import YahooFinance
from sensible.brokers.base import Credentials
from sensible.data.base import DataBase
from sensible.data.tickers import Ticker

# %%
creds = Credentials(username="foo", password="bar")
data = DataBase(ticker=Ticker.GOOG)
broker = YahooFinance(credentials=creds)

# %%
data = broker.get_data(data=data)
# Out:
# /Users/romilshah/Documents/projects/sensible/.venv/lib/python3.10/site-packages/yfinance/utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')

# %%
data.data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-01-10 00:00:00-05:00  142.520004  144.524994  142.460007  143.800003
# 2024-01-11 00:00:00-05:00  144.895004  146.660004  142.214996  143.669998
# 2024-01-12 00:00:00-05:00  144.339996  144.740005  143.360001  144.240005
# 2024-01-16 00:00:00-05:00  143.429993  145.839996  143.056000  144.080002
# 2024-01-17 00:00:00-05:00  142.910004  143.410004  140.509995  142.889999
# 2024-01-18 00:00:00-05:00  143.440002  145.585007  143.350006  144.990005
# 2024-01-19 00:00:00-05:00  146.304993  148.039993  145.800003  147.970001
# 2024-01-22 00:00:00-05:00  148.710007  150.014999  147.580002  147.710007
# 2024-01-23 00:00:00-05:00  147.720001  148.860001  147.190002  148.679993
# 2024-01-24 00:00:00-05:00  150.289993  151.570007  149.839996  150.350006
# 2024-01-25 00:00:00-05:00  151.740005  154.759995  151.220001  153.639999
# 2024-01-26 00:00:00-05:00  152.869995  154.110001  152.800003  153.789993
# ...
